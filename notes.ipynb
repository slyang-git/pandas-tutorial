# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./datasets/supermarket_sales.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.groupby("Payment").groups
# Out:
# {'Cash': [1, 11, 14, 15, 26, 28, 29, 31, 32, 39, 41, 42, 43, 44, 45, 50, 51, 55, 56, 58, 59, 64, 65, 68, 69, 71, 73, 79, 84, 86, 88, 89, 90, 97, 99, 100, 101, 102, 103, 104, 107, 108, 109, 112, 126, 130, 131, 132, 135, 137, 138, 141, 142, 154, 156, 161, 166, 168, 172, 180, 181, 187, 192, 195, 196, 201, 202, 211, 214, 216, 217, 222, 223, 224, 228, 230, 232, 233, 238, 243, 245, 246, 253, 254, 255, 262, 263, 267, 271, 273, 275, 276, 278, 282, 284, 285, 286, 287, 289, 292, ...], 'Credit card': [2, 8, 9, 16, 17, 18, 22, 25, 27, 30, 33, 46, 48, 53, 60, 63, 70, 75, 76, 77, 80, 83, 87, 93, 94, 106, 111, 114, 115, 120, 121, 122, 123, 125, 127, 133, 136, 140, 143, 145, 147, 148, 149, 150, 151, 152, 155, 160, 162, 164, 167, 169, 171, 173, 176, 177, 184, 189, 190, 194, 198, 199, 200, 204, 206, 209, 213, 215, 219, 225, 231, 236, 237, 240, 241, 242, 244, 248, 249, 251, 252, 256, 259, 265, 266, 268, 272, 279, 280, 281, 288, 290, 300, 301, 303, 312, 318, 324, 328, 331, ...], 'Ewallet': [0, 3, 4, 5, 
# ...

# %%
df.groupby("Payment")["Quantity"].sum()
# Out:
# Payment
# Cash           1896
# Credit card    1722
# Ewallet        1892
# Name: Quantity, dtype: int64

# %%
df.groupby("Payment")["Quantity"].agg([np.sum, np.mean, np.max, np.min])
# Out:
#               sum      mean  amax  amin
# Payment
# Cash         1896  5.511628    10     1
# Credit card  1722  5.536977    10     1
# Ewallet      1892  5.484058    10     1

# %%
df.groupby("Payment")["Quantity"].count()
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# Name: Quantity, dtype: int64

# %%
df.groupby(["Payment", "Customer type"])["Quantity"].sum()
# Out:
# Payment      Customer type
# Cash         Member            885
#              Normal           1011
# Credit card  Member           1002
#              Normal            720
# Ewallet      Member            898
#              Normal            994
# Name: Quantity, dtype: int64

# %%
df.groupby(["Payment", "Customer type"])[
    ["Quantity", "Unit price"]].sum().columns
# Out:
# Index(['Quantity', 'Unit price'], dtype='object')

# %%
rng = pd.date_range("2023/1/1", periods=365, freq="D")
rng
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
data = {
    "Name": ["Alice", "Bob", "Alice", "Bob", "Charlie"],
    "Month": ["Jan", "Jan", "Feb", "Feb", "Jan"],
    "Sales": [100, 200, 150, 300, 250],
}
df2 = pd.DataFrame(data)
df2
# Out:
#       Name Month  Sales
# 0    Alice   Jan    100
# 1      Bob   Jan    200
# 2    Alice   Feb    150
# 3      Bob   Feb    300
# 4  Charlie   Jan    250

# %%
pivot_table = df2.pivot_table(
    values="Sales", index="Name", columns="Month", aggfunc="sum"
)
pivot_table
# Out:
# Month      Feb    Jan
# Name
# Alice    150.0  100.0
# Bob      300.0  200.0
# Charlie    NaN  250.0

# %%
df3 = pd.read_excel("./datasets/sales-funnel.xlsx")
df3.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df3["Status"] = df3["Status"].astype("category")
df3["Status"].cat.set_categories(["won", "pending", "presented", "declined"])
df3
# Out:
#     Account                          Name            Rep        Manager  \
# 0    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 1    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 2    714466               Trantow-Barrows   Craig Booker   Debra Henley
# 3    737550  Fritsch, Russel and Anderson   Craig Booker   Debra Henley
# 4    146832                  Kiehn-Spinka  Daniel Hilton   Debra Henley
# 5    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 6    218895                     Kulas Inc  Daniel Hilton   Debra Henley
# 7    412290                 Jerde-Hilpert     John Smith   Debra Henley
# 8    740150                    Barton LLC     John Smith   Debra Henley
# 9    141962                    Herman LLC    Cedric Moss  Fred Anderson
# 10   163416                   Purdy-Kunde    Cedric Moss  Fred Anderson
# 11   239344                    Stokes LLC    Cedric Moss  Fred Anderson
# ...

# %%
pd.pivot_table(df3, index=["Name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
# ...
